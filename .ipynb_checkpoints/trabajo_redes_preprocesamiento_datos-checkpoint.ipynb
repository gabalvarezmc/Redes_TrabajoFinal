# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: networkx in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from -r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: matplotlib in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: openpyxl in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from -r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: requests in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from -r requirements.txt (line 5)) (2.32.3)
# Collecting scipy (from -r requirements.txt (line 6))
#   Downloading scipy-1.15.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: et-xmlfile in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from openpyxl->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (2024.12.14)
# Requirement already satisfied: six>=1.5 in c:\magister\3er trimestre\ciencia de redes\redes_trabajofinal\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Downloading scipy-1.15.0-cp310-cp310-win_amd64.whl (43.9 MB)
#    ---------------------------------------- 0.0/43.9 MB ? eta -:--:--
#    --------------- ------------------------ 17.3/43.9 MB 83.9 MB/s eta 0:00:01
#    ---------------------------------------  43.0/43.9 MB 105.2 MB/s eta 0:00:01
#    ---------------------------------------- 43.9/43.9 MB 87.3 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.0

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import requests
import requests

# %%
df_base = pd.read_excel("consolidado_reviews_Los_Rios.xlsx")

# %%
print(df_base.head())
print(df_base.columns)
# Out:
#     N                     place_id                   name  \
# 0  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 1  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 2  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 3  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 4  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
#
#                               id_review                         user_name  \
# 0  ChdDSUhNMG9nS0VJQ0FnSURYbzgzN29BRRAB                     angie cardona
# 1  ChdDSUhNMG9nS0VJQ0FnSURYMmJPampnRRAB                     Fabian Aruani
# 2   ChZDSUhNMG9nS0VJQ0FnSURYb01lUkFREAE                   Nataniel Lavado
# 3  ChdDSUhNMG9nS0VJQ0FnSUNYLTdiY2tBRRAB  Leonardo Enrique García Riquelme
# 4  ChdDSUhNMG9nS0VJQ0FnSUNYdTdlYTZBRRAB                    Andres Herrera
#
#               id_usuario  stars  \
# 0  103326493536057771398      5
# 1  117348510194376829755      3
# 2  115312318540115775891      5
# 3  100519139671583772741      4
# 4  117104494720799796058      5
#
#                                          link_review  \
# 0  https://www.google.com/maps/contrib/1033264935...
# 1  https://www.google.com/maps/contrib/1173485101...
# 2  https://www.google.com/maps/contrib/1153123185...
# 3  https://www.google.com/maps/contrib/1005191396...
# 4  https://www.google.com/maps/contrib/1171044947...
#
#                         fecha  \
# 0  2024-10-30T17:50:02.384466
# 1  2024-10-29T11:17:02.664924
# 2  2024-10-22T20:31:57.541034
# 3  2024-10-21T02:57:42.891824
# 4  2024-10-21T01:39:11.791360
#
#                                               review    Latitud   Longitud
# 0  Excelente atención, la comida fue deliciosa!! ... -39.873253 -71.890961
# 1                                                NaN -39.873253 -71.890961
# 2                   Atendido por sus dueños exelente -39.873253 -71.890961
# 3                                                NaN -39.873253 -71.890961
# 4                                                NaN -39.873253 -71.890961
# Index(['N', 'place_id', 'name', 'id_review', 'user_name', 'id_usuario',
#        'stars', 'link_review', 'fecha', 'review', 'Latitud', 'Longitud'],
#       dtype='object')

# %%
list_placeids = df_base['place_id'].unique()
print(len(list_placeids))
print(len(df_base['id_usuario'].unique()))
# Out:
# 1390
# 205836

# %%
API_KEY = 'AIzaSyAGF3PqgVlwcuPSGTCLGlbeUWIwhwHZyGw'
def get_geocode(api_key, place_id):
    # URL base de la API de Geocoding
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"place_id": place_id, "key": api_key}
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data.get("results"):
            result = data["results"][0]
            latitude = result["geometry"]["location"]["lat"]
            longitude = result["geometry"]["location"]["lng"]
            return {
                "latitude": latitude,
                "longitude": longitude
            }
        else:
            return {"error": "No se encontraron resultados"}
    else:
        return {"error": f"Error en la solicitud: {response.status_code}"}


for place_id in list_placeids:
    resultado = get_geocode(API_KEY, place_id)
    if "error" in resultado:
        print(f"Error para {place_id}: {resultado['error']}")
    else:
        df_base.loc[df_base['place_id'] == place_id, 'Latitud'] = resultado["latitude"]
        df_base.loc[df_base['place_id'] == place_id, 'Longitud'] = resultado["longitude"]

# %%
#Error para ChIJz5dvdE9DFpYRAzONxAT0Qrk: No se encontraron resultados
# Error para ChIJoTdoGVV1PZYRGf483bWJ2YI: No se encontraron resultados
# Error para ChIJ2VZ5pWMysmYRMR5WVfBDy7A: No se encontraron resultados
# Error para ChIJbwCrUkiBE5YRdU1YSjs46fM: No se encontraron resultados
# Error para ChIJGStsmnu-FpYRqI4LZzhkxzI: No se encontraron resultados
df_modificado = df_base[['N', 'place_id', 'Latitud', 'Longitud', 'name', 'id_usuario', 'stars', 'fecha']]
df_modificado.to_excel("consolidado_reviews_Los_Rios_con_latlon.xlsx", index=False)

# %%
df_only_nodos = df_modificado[['N', 'name', 'Latitud', 'Longitud', 'stars']].groupby(['N', 'name', 'Latitud', 'Longitud']).mean().reset_index()
df_only_nodos.to_excel("nodos_Los_Rios.xlsx", index=False)

# %%
# Graficar nube de puntos con latitud y longitud
plt.figure(figsize=(10, 10))
plt.scatter(df_only_nodos["Latitud"], df_only_nodos["Longitud"], s=100, alpha=0.5)
plt.title("Nube de puntos de los lugares")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
